# %%
#imports
import pandas as pd
from sqlalchemy import create_engine
import pymysql
pymysql.install_as_MySQLdb()

engine = create_engine("mysql://root:password@localhost/etl_project")
conn = engine.connect()

# %%
#get school json into dataframe
school="../Assets/schoolInfo.json"

sdf=pd.read_json(school)

sdf.head()
# Out:
#    acceptance-rate  act-avg aliasNames  businessRepScore       city  \
# 0              7.0     32.0       None               NaN  Princeton
# 1              5.0     32.0       None               NaN  Cambridge
# 2              8.0     32.0   UChicago               NaN    Chicago
# 3              6.0     32.0       None               NaN  New Haven
# 4              6.0     32.0       None               NaN   New York
#
#    cost-after-aid            displayName  engineeringRepScore  enrollment  \
# 0         16793.0   Princeton University                  4.1      5400.0
# 1         16338.0     Harvard University                  3.6      6710.0
# 2         27767.0  University of Chicago                  NaN      5941.0
# 3         18385.0        Yale University                  3.4      5472.0
# 4         21041.0    Columbia University                  3.8      6113.0
#
#    hs-gpa-avg  ...              rankingType  region  sat-avg  \
# ...

# %%
#clean dataframe
sdf_clean= sdf[['displayName','city','state']].copy()

sdf_clean.head()
# Out:
#              displayName       city state
# 0   Princeton University  Princeton    NJ
# 1     Harvard University  Cambridge    MA
# 2  University of Chicago    Chicago    IL
# 3        Yale University  New Haven    CT
# 4    Columbia University   New York    NY

# %%
#join
state_list = pd.read_sql_query("Select * from state", con=engine)

merged= sdf_clean.merge(state_list, left_on="state", right_on="state_abbv", how='left')

merged.head()
# Out:
#              displayName       city state  state_id     state_name state_abbv
# 0   Princeton University  Princeton    NJ        25     New Jersey         NJ
# 1     Harvard University  Cambridge    MA        34  Massachusetts         MA
# 2  University of Chicago    Chicago    IL        14       Illinois         IL
# 3        Yale University  New Haven    CT         7    Connecticut         CT
# 4    Columbia University   New York    NY        27       New York         NY

# %%
#drop columns
merged.drop(columns={'state','state_name','state_abbv'}, inplace=True)

# %%
#rename columns
merged.rename(columns={'displayName':'college_name','city':'college_city'}, inplace=True)
merged.head()
# Out:
#             college_name college_city  state_id
# 0   Princeton University    Princeton        25
# 1     Harvard University    Cambridge        34
# 2  University of Chicago      Chicago        14
# 3        Yale University    New Haven         7
# 4    Columbia University     New York        27

# %%
#insert into database
merged.to_sql(name="college_list",con=engine,if_exists='append', index=False)

# %%
pd.read_sql_query("Select * from college_list", con=engine)
# Out:
#      college_list_id                              college_name  \
# 0                  1                      Princeton University
# 1                  2                        Harvard University
# 2                  3                     University of Chicago
# 3                  4                           Yale University
# 4                  5                       Columbia University
# 5                  6     Massachusetts Institute of Technology
# 6                  7                       Stanford University
# 7                  8                University of Pennsylvania
# 8                  9                           Duke University
# 9                 10        California Institute of Technology
# 10                11                         Dartmouth College
# 11                12                  Johns Hopkins University
# 12                13                   Northwestern University
# 13                14                          Brown University
# ...
